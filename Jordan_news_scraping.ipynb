# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pyodbc
from urllib.parse import urljoin
from datetime import datetime, timedelta
import re

# %%
# base_url = "https://royanews.tv"

headers = {'User-Agent': 'Mozilla/5.0'}

sections = [
    "https://www.jordannews.jo/Category/5/Business",
    "https://www.jordannews.jo/Section-33/Trade-Industry"
    # ,"https://www.jordannews.jo/Section-30/Entrepreneurship"
]


# response = requests.get(page_url, headers=headers)
# soup = BeautifulSoup(response.content, "html.parser")

# %%
article_links = []

for page_url in sections:
    try:
        response = requests.get(page_url, headers=headers)
        soup = BeautifulSoup(response.content, "html.parser")

        for a in soup.find_all("a", href=True):
            href = a["href"].strip()

            # روابط Jordan News (Economy, Business, Trade-Industry, All فقط)
            if page_url.startswith("https://www.jordannews.jo") and any(kw in href for kw in ["Economy", "Business", "Trade-Industry", "All"]):
                full_link = urljoin(page_url, href)
                if full_link not in article_links:
                    article_links.append(full_link)


    except Exception as e:
        print(f"❌ Error while scraping {page_url}: {e}")

print(f"🔗 Total extracted links: {len(article_links)}")
# Out:
# 🔗 Total extracted links: 82

# %%
valid_links = []
now = datetime.now()

# %%
for link in article_links:
    try:
        res = requests.get(link, headers=headers)
        soup = BeautifulSoup(res.content, "html.parser")

        pub_text = ""
        pub_time = None

        pub_div = soup.find("div", class_="pup_date_news")
        if pub_div:
            pub_text = pub_div.get_text(strip=True).replace("نشر :", "").replace("Published:", "").strip()
            pub_text = pub_text.replace("|", "").strip()

        if not pub_text:
            main_date = soup.select_one("div.story span.DateTime")
            if main_date:
                pub_text = main_date.get_text(strip=True)
            else:
                 time_byline = soup.select_one("p.byline span.TimeDate")
                 if time_byline:
                       pub_text = time_byline.get_text(strip=True)


        # ⏰ تحويل الوقت
        if "منذ" in pub_text or "ago" in pub_text:
            if "ساعتين" in pub_text or "two hours" in pub_text:
                pub_time = now - timedelta(hours=2)
            elif "منذ ساعة" in pub_text or "an hour" in pub_text or "hour ago" in pub_text:
                pub_time = now - timedelta(hours=1)    
            elif "ساعات" in pub_text or "ساعة" in pub_text or "hour" in pub_text:
                hours = int(re.search(r"\d+", pub_text).group())
                pub_time = now - timedelta(hours=hours)
            elif "دقيقتين" in pub_text or "two minutes" in pub_text:
                pub_time = now - timedelta(minutes=2)
            elif "منذ دقيقة" in pub_text or "a minute" in pub_text:
                pub_time = now - timedelta(minutes=1)    
            elif "دقائق" in pub_text or "دقيقة" in pub_text or "minute" in pub_text:
                minutes = int(re.search(r"\d+", pub_text).group())
                pub_time = now - timedelta(minutes=minutes)
            elif "m ago" in pub_text:
                match = re.search(r"(\d+)\s*m", pub_text)
                if match:
                     minutes = int(match.group(1))
                     pub_time = now - timedelta(minutes=minutes)                  
            elif "h ago" in pub_text:
                match = re.search(r"(\d+)\s*h", pub_text)
                if match:
                    hours = int(match.group(1))
                    pub_time = now - timedelta(hours=hours)     
        elif "Published :" in pub_text and re.search(r"\d{2}-\d{2}-\d{4} \d{2}:\d{2}", pub_text):
            pub_text = pub_text.replace("Published :", "").strip()
            pub_time = datetime.strptime(pub_text, "%d-%m-%Y %H:%M")

        # ✅ الفلترة
        if pub_time and (now - pub_time).total_seconds() <= 86400:
            valid_links.append((link, pub_text))
            print(f"✅ Added ({pub_text}) → {link}")
        else:
            print(f"🕒 Ignored ({pub_text}) → {link}")
    except Exception as e:
        print(f"❌ Error while checking {link}: {e}")

# 📌 عرض النتائج النهائية
print("\n📌 Articles within the last 24 hours:")
for i, (link, pub_text) in enumerate(valid_links, 1):
    print(f"{i}. {link} 🕒 {pub_text}")
# Out:
# 🕒 Ignored () → https://www.jordannews.jo/Category/5/Business
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry
# 🕒 Ignored () → https://www.jordannews.jo/Section-111/All
# 🕒 Ignored () → https://www.jordannews.jo/Section-126/All
# ✅ Added (52m ago) → https://www.jordannews.jo/Section-113/All/Housing-Bank-Holds-its-52nd-Annual-General-Assembly-Approval-of-2024-Financial-Statements-and-30-Cash-Dividends-Distribution-JOD-150-3-Million-Net-Profits-for-2024-and-Major-Achievements-across-Key-P-41430
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All
# ✅ Added (58m ago) → https://www.jordannews.jo/Section-113/All/Applied-Science-Private-University-Leads-Jordanian-Universities-and-Achieves-a-Major-Asian-Milestone-in-the-2025-Times-Ranking-41429
# ✅ Added (18 h ago) → https://www.jordannews.jo/Section-112/Economy/Energy-Regulatory-Authority-100-000-Plastic-Gas-Cylinders-to-Be-Available-in-Markets-by-End-of-June-41403
# ✅ Added (19 h ago) → https://www.jordannews.jo/Section-113/All/Slight-Increase-in-Global-Oil-Prices-41406
# ✅ Added (19 h ago) → https://www.jordannews.jo/Section-113/All/European-Markets-Close-Higher-Across-the-Board-41405
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/3D-Seismic-Survey-for-Oil-and-Gas-Exploration-Launched-in-Eastern-Jafr-41262
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Global-Oil-Prices-Decline-41264
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Announcement-of-the-Launch-of-the-Integrity-Ambassadors-in-Universities-Initiative-from-Applied-Science-University-41291
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Faculty-of-Applied-Medical-Sciences-at-Al-Zaytoonah-University-Organizes-Physical-Therapy-in-the-Arab-World-Present-and-Future-Meeting-41380
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/24-3-Million-from-European-Investment-Bank-to-Reduce-Water-Loss-in-Jordan-41240
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Oil-Prices-See-Slight-Increase-Globally-41373
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/JoPetrol-and-Jordan-Gas-Sign-Strategic-Agreement-to-Launch-Watani-The-National-Advanced-Natural-Gas-Company-to-Enhance-Energy-Sustainability-in-Jordan-41371
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/15-Government-AI-Projects-Completed-41227
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Umniah-Appoints-Faisal-Al-Jalahma-as-Acting-CEO-41360
# ✅ Added (19 h ago) → https://www.jordannews.jo/Section-112/Economy/Chinese-and-Japanese-Stocks-Continue-to-Gain-41404
# ✅ Added (22 h ago) → https://www.jordannews.jo/Section-112/Economy/21-Carat-Gold-Priced-at-68-Dinars-per-Gram-in-the-Local-Market-41396
# ✅ Added (22 h ago) → https://www.jordannews.jo/Section-112/Economy/JEBA-President-The-European-Market-Represents-a-Strong-Opportunity-to-Expand-and-Diversify-Jordan-s-Exports-41395
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Ministry-of-Industry-and-Trade-Issues-Tender-to-Purchase-Wheat-41379
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Amman-Stock-Exchange-Closes-Higher-41372
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Tax-Department-Extension-for-Submitting-Audited-Financial-Statements-Until-May-25-41366
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Jordan-Ahli-Bank-Renews-Partnership-with-Tkiyet-Um-Ali-Aligning-with-UN-Sustainable-Development-Goals-41365
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Housing-Bank-Launches-2025-Auto-Loan-Campaign-with-Interest-Rates-Starting-at-3-99-Fixed-41359
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Gold-Price-for-21-Carat-Reaches-68-Dinars-per-Gram-in-Local-Market-41356
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/For-the-first-time-in-the-Kingdom-Free-5G-Service-Unprecedented-Rewards-for-All-41354
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Details-of-Local-Gold-Price-Increase-on-Wednesday-41351
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Amman-Stock-Exchange-Closes-Trading-Lower-41350
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/U-S-Dollar-Rises-Broadly-Against-Major-Currencies-41331
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Social-Security-Corporation-11-850-Establishments-Have-Opted-to-Reschedule-Debts-Totaling-396-Million-Dinars-41330
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Oil-Prices-Rise-as-U-S-Crude-Inventories-Decline-41326
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Significant-Drop-in-Local-Gold-Prices-41325
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/For-the-First-Time-Gold-Price-in-Syria-Surpasses-1-1-Million-Syrian-Pounds-per-Gram-41312
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Amman-Stock-Exchange-Closes-on-a-Decline-41308
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Aqaba-Container-Terminal-Acquires-13M-State-of-the-Art-Ship-to-Shore-Crane-41304
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/Global-Oil-Prices-Rise-41319
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Bustami-and-Saheb-Group-Nissan-Middle-East-A-24-growth-in-sales-during-the-first-nine-months-of-2024-41301
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Social-Security-Corporation-Renews-Call-for-0-Interest-Installment-Plan-on-Establishments-Debts-Until-End-of-June-and-for-the-Tourism-Sector-Until-Year-End-41298
# 🕒 Ignored () → https://www.jordannews.jo/Section-112/Economy/21-Carat-Gold-Reaches-71-Dinars-Locally-41294
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/TotalEnergies-Reopens-Two-Service-Stations-in-Jordan-After-Temporary-Closure-41272
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Kia-EV3-Wins-2025-World-Car-of-the-Year-41267
# 🕒 Ignored () → https://www.jordannews.jo/Section-113/All/Ayla-Celebrates-Silica-s-Renewal-of-Prestigious-Global-Green-Key-Certification-41266
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Kia-hosts-UAE-Tasman-Roadshow-marking-strong-entry-into-the-pickup-truck-segment-41036
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Kia-Takes-Four-Victories-in-2025-iF-Design-Awards-Showcasing-Design-and-Innovation-Excellence-40950
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Amman-Stock-Exchange-Suspends-Trading-of-Shares-of-Companies-That-Have-Not-Disclosed-Their-Financial-Data-40883
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jerusalem-Insurance-Organizes-a-Free-Medical-Day-as-Part-of-Its-Commitment-to-Social-Responsibility-40166
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Orange-Jordan-Sponsors-Model-United-Nations-Conferences-in-Several-Schools-to-Support-Future-Leaders-40082
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Top-Tips-for-Investing-in-Gold-36706
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/President-of-Chamber-of-Commerce-urges-further-trade-with-Turkey-31192
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-had-7-month-export-surge-and-import-drop-31117
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-s-trade-exceeds-23-billion-with-partner-countries-28862
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Putin-holds-talks-to-establish-free-zones-with-Iran-UAE-and-Egypt-28855
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Iraqi-oil-exports-covers-7-of-Jordan-s-needs-says-minister-28468
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Trade-union-federation-calls-for-freedom-of-union-organization-28379
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-s-trade-surplus-with-US-stands-at-JD625m-in-2022-27248
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Qatar-increases-imports-of-Jordanian-foodstuff-during-World-Cup-24774
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-Oman-announce-details-of-signed-industrial-memo-24783
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Gold-price-fluctuations-tied-to-global-politics-economy-syndicate-24644
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/ACC-exports-over-last-10-months-stand-at-JD742m-statistics-24142
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Strong-McDonald-s-results-showcase-advantage-amid-inflation-23786
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Drop-in-foreign-exchange-slashes-prices-of-imported-goods-stakeholder-23746
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Foreign-trade-on-recovery-path-says-JBA-president-23669
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Korean-companies-produce-20-of-Jordan-s-electricity-envoy-22808
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/JCC-chief-hails-proposal-for-Egyptian-gas-in-industrial-cities-22618
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-Saudi-Arabia-discuss-electric-connectivity-22456
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-Gulf-Economic-Forum-aims-to-boost-trade-and-economic-ties-22437
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-Egypt-discuss-expanding-registration-of-Jordan-medicines-22405
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Qatar-to-participate-in-Jordanian-economic-forum-JCC-22292
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Iraqi-oil-starts-flowing-into-Jordan-Thiabat-22290
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Online-platform-launched-to-facilitate-export-activities-22152
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/European-market-key-for-Jordan-exports-JEBA-22072
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Romania-imports-most-goods-from-Jordan-in-EU-21884
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Egypt-scraps-hiked-fee-on-Jordanian-truckers-21828
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-s-trade-deficit-with-EU-countries-at-JD1-2b-21769
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Industrial-producer-prices-up-16-84-21770
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Jordan-Qatar-trade-balance-at-3-17b-in-10-years-21725
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/JBA-Iraqi-Business-Council-talk-future-cooperation-21729
# 🕒 Ignored () → https://www.jordannews.jo/Section-33/Trade-Industry/Gov-t-dissolves-boards-of-chambers-of-industry-and-commerce-21713
#
# 📌 Articles within the last 24 hours:
# 1. https://www.jordannews.jo/Section-113/All/Housing-Bank-Holds-its-52nd-Annual-General-Assembly-Approval-of-2024-Financial-Statements-and-30-Cash-Dividends-Distribution-JOD-150-3-Million-Net-Profits-for-2024-and-Major-Achievements-across-Key-P-41430 🕒 52m ago
# 2. https://www.jordannews.jo/Section-113/All/Applied-Science-Private-University-Leads-Jordanian-Universities-and-Achieves-a-Major-Asian-Milestone-in-the-2025-Times-Ranking-41429 🕒 58m ago
# 3. https://www.jordannews.jo/Section-112/Economy/Energy-Regulatory-Authority-100-000-Plastic-Gas-Cylinders-to-Be-Available-in-Markets-by-End-of-June-41403 🕒 18 h ago
# 4. https://www.jordannews.jo/Section-113/All/Slight-Increase-in-Global-Oil-Prices-41406 🕒 19 h ago
# 5. https://www.jordannews.jo/Section-113/All/European-Markets-Close-Higher-Across-the-Board-41405 🕒 19 h ago
# 6. https://www.jordannews.jo/Section-112/Economy/Chinese-and-Japanese-Stocks-Continue-to-Gain-41404 🕒 19 h ago
# 7. https://www.jordannews.jo/Section-112/Economy/21-Carat-Gold-Priced-at-68-Dinars-per-Gram-in-the-Local-Market-41396 🕒 22 h ago
# 8. https://www.jordannews.jo/Section-112/Economy/JEBA-President-The-European-Market-Represents-a-Strong-Opportunity-to-Expand-and-Diversify-Jordan-s-Exports-41395 🕒 22 h ago

# %%
final_links = set()

for item in valid_links:
    if isinstance(item, tuple) and len(item) >= 1:
        link = item[0]
        if link and link.startswith("http"):
            final_links.add(link)

print("\n📌 روابط المقالات خلال آخر 24 ساعة (final_links):")
for i, link in enumerate(final_links, 1):
    print(f"{i}. {link}")
# Out:
# 📌 روابط المقالات خلال آخر 24 ساعة (final_links):
# 1. https://www.jordannews.jo/Section-113/All/Housing-Bank-Holds-its-52nd-Annual-General-Assembly-Approval-of-2024-Financial-Statements-and-30-Cash-Dividends-Distribution-JOD-150-3-Million-Net-Profits-for-2024-and-Major-Achievements-across-Key-P-41430
# 2. https://www.jordannews.jo/Section-112/Economy/JEBA-President-The-European-Market-Represents-a-Strong-Opportunity-to-Expand-and-Diversify-Jordan-s-Exports-41395
# 3. https://www.jordannews.jo/Section-113/All/Applied-Science-Private-University-Leads-Jordanian-Universities-and-Achieves-a-Major-Asian-Milestone-in-the-2025-Times-Ranking-41429
# 4. https://www.jordannews.jo/Section-113/All/European-Markets-Close-Higher-Across-the-Board-41405
# 5. https://www.jordannews.jo/Section-112/Economy/Chinese-and-Japanese-Stocks-Continue-to-Gain-41404
# 6. https://www.jordannews.jo/Section-113/All/Slight-Increase-in-Global-Oil-Prices-41406
# 7. https://www.jordannews.jo/Section-112/Economy/21-Carat-Gold-Priced-at-68-Dinars-per-Gram-in-the-Local-Market-41396
# 8. https://www.jordannews.jo/Section-112/Economy/Energy-Regulatory-Authority-100-000-Plastic-Gas-Cylinders-to-Be-Available-in-Markets-by-End-of-June-41403

# %%
import os
# images_folder = "images"
os.makedirs('news_images', exist_ok=True)

# %%
data = []

for link in final_links:
    try:
        res = requests.get(link, headers=headers)
        soup = BeautifulSoup(res.content, "html.parser")

        # العنوان
        title_tag = soup.find("h1", class_="details-news-title") or soup.find("div", class_="news_main_title_mob")
        title = title_tag.get_text(strip=True) if title_tag else "No Title"

        # المحتوى
        content_div = soup.find("div", id="atricle-text") or soup.find("div", class_="Newsbody")

        if content_div:
    # احذف كل وسوم الإعلانات <addadscommand> لو فيه
            for ad in content_div.find_all('addadscommand'):
                ad.decompose()

    # احذف قسم "Read More" لو موجود
            read_more_section = content_div.find('div', class_="news-items")
            if read_more_section:
                 read_more_section.decompose()

    # بعد التنظيف، خذ كل النص المكتوب
            content = content_div.get_text(separator="\n", strip=True)
        else:
            content = "No Content"

        # الصورة
        img_tag = soup.find("img")
        img_url = urljoin(link, img_tag["src"]) if img_tag and img_tag.get("src") else None

        # حفظ الصورة
        clean_title = re.sub(r'[\\/:*?"<>|]', '', title)
        if img_url:
            img_data = requests.get(img_url).content
            img_path = os.path.join("news_images", f"{clean_title}.jpg")
            with open(img_path, "wb") as f:
                f.write(img_data)

        data.append({
            "Title": title,
            "Content": content,
            "Image": img_url,
            "Link": link
        })
        print(f"✅ Saved: {title}")
    except Exception as e:
        print(f"❌ Error in {link}: {e}")
# Out:
# ✅ Saved: Housing Bank Holds its 52nd Annual General Assembly Approval of 2024 Financial Statements and 30% Cash Dividends Distribution JOD 150.3 Million Net Profits for 2024 and Major Achievements across Key P
# ✅ Saved: JEBA President: The European Market Represents a Strong Opportunity to Expand and Diversify Jordan's Exports
# ✅ Saved: Applied Science Private University Leads Jordanian Universities and Achieves a Major Asian Milestone in the 2025 Times Ranking
# ✅ Saved: European Markets Close Higher Across the Board
# ✅ Saved: Chinese and Japanese Stocks Continue to Gain
# ✅ Saved: Slight Increase in Global Oil Prices
# ✅ Saved: 21-Carat Gold Priced at 68 Dinars per Gram in the Local Market
# ✅ Saved: Energy Regulatory Authority: 100,000 Plastic Gas Cylinders to Be Available in Markets by End of June

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                Title  \
# 0  Housing Bank Holds its 52nd Annual General Ass...
# 1  JEBA President: The European Market Represents...
# 2  Applied Science Private University Leads Jorda...
# 3     European Markets Close Higher Across the Board
# 4       Chinese and Japanese Stocks Continue to Gain
# 5               Slight Increase in Global Oil Prices
# 6  21-Carat Gold Priced at 68 Dinars per Gram in ...
# 7  Energy Regulatory Authority: 100,000 Plastic G...
#
#                                              Content  \
# 0  The Housing Bank for Trade and\nFinance (HBTF)...
# 1  The President of the Jordanian-European Busine...
# 2  Applied Science Private University (ASU) conti...
# 3  European stock markets closed higher across th...
# 4  Stocks in China and Hong Kong rose slightly on...
# 5  Global oil prices rose slightly on Saturday at...
# 6  Gold prices for 21-carat, the most in-demand a...
# 7  The Chairman of the Board of Commissioners of ...
#
#                                            Image  \
# 0  https://www.jordannews.jo/App_images/logo.png
# 1  https://www.jordannews.jo/App_images/logo.png
# 2  https://www.jordannews.jo/App_images/logo.png
# 3  https://www.jordannews.jo/App_images/logo.png
# 4  https://www.jordannews.jo/App_images/logo.png
# 5  https://www.jordannews.jo/App_images/logo.png
# 6  https://www.jordannews.jo/App_images/logo.png
# 7  https://www.jordannews.jo/App_images/logo.png
#
#                                                 Link
# 0  https://www.jordannews.jo/Section-113/All/Hous...
# 1  https://www.jordannews.jo/Section-112/Economy/...
# 2  https://www.jordannews.jo/Section-113/All/Appl...
# 3  https://www.jordannews.jo/Section-113/All/Euro...
# 4  https://www.jordannews.jo/Section-112/Economy/...
# 5  https://www.jordannews.jo/Section-113/All/Slig...
# 6  https://www.jordannews.jo/Section-112/Economy/...
# 7  https://www.jordannews.jo/Section-112/Economy/...

# %%
df.to_excel("Jordan_news_articles.xlsx", index=False, engine='openpyxl')

# %%
articles_df = pd.read_excel("Jordan_news_articles.xlsx", engine='openpyxl')
# articles_df

# %%
import pyodbc,  sys 

conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'

                      'SERVER=.\\SQLEXPRESS;'

                      'DATABASE=Scraping;'

                      'Trusted_Connection=yes;'
                      
                      'Encrypt=no')
cursor = conn.cursor()

# %%
# cursor.execute("DELETE FROM Roya_Articles")
# conn.commit()
cursor.execute("TRUNCATE TABLE Jordan_news_articles")
conn.commit()

# %%
for index, row in df.iterrows():
    cursor.execute(
        "INSERT INTO Jordan_news_articles (title, content, image, link) VALUES (?, ?, ?, ?)",
        (row['Title'], row['Content'], row['Image'], row['Link'])
    )

conn.commit()
